# %% [markdown]
# <a href="https://colab.research.google.com/github/GabrielMarcuzzo/python4all/blob/main/PROGRAMA_II__WEB_SCRAPING__JSON__iTunes_Apple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Programa II:

# Baixar os dados da API iTunes sobre as músicas de um determinado grupo ou artista e gerar uma planilha Excel com esses dados:

import pandas as pd
import requests
import json

base_site = "https://itunes.apple.com/search"
r = requests.get(base_site, params = {"term": "The Beatles", "country": "us"})
info = r.json()
songs_df = pd.DataFrame(info["results"])
songs_df.to_excel("musicas_beatles_info.xlsx")
songs_df
# Out:
#    wrapperType           kind       trackId  \
# 0        track  feature-movie  1.619195e+09
# 1        track  feature-movie  1.650285e+09
# 2        track  feature-movie  4.983044e+08
# 3        track  feature-movie  1.057397e+09
# 4        track  feature-movie  1.560230e+09
# 5        track  feature-movie  1.231264e+09
# 6        track  feature-movie  1.617351e+09
# 7        track     tv-episode  1.557129e+09
# 8    audiobook            NaN           NaN
# 9    audiobook            NaN           NaN
# 10   audiobook            NaN           NaN
# 11   audiobook            NaN           NaN
# 12   audiobook            NaN           NaN
# 13   audiobook            NaN           NaN
# 14   audiobook            NaN           NaN
# 15   audiobook            NaN           NaN
# 16   audiobook            NaN           NaN
# 17   audiobook            NaN           NaN
# 18   audiobook            NaN           NaN
# 19   audiobook            NaN           NaN
# ...
