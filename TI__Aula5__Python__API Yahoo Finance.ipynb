# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
import matplotlib.pyplot as plt

tickers = ["TSLA"]
stock_prices_br = pd.DataFrame()
for t in tickers:
	 stock_prices_br[t] = wb.DataReader(t, data_source = "yahoo", start ="2020-1-1")["Adj Close"]

stock_prices_br.plot(figsize = (15, 6))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
import matplotlib.pyplot as plt

tickers = ["PETR4.SA", "VALE3.SA", "ITUB4.SA", "ABEV3.SA", "BBDC4.SA"]
stock_prices_br = pd.DataFrame()
for t in tickers:
	stock_prices_br[t] = wb.DataReader(t, data_source = "yahoo", start ="2020-1-1")["Adj Close"]

(stock_prices_br/ stock_prices_br.iloc[0] * 100).plot(figsize = (15, 6));
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import pandas as pd
import requests
import json

base_site = "https://itunes.apple.com/search"

r = requests.get(base_site, params = {"term": "elvis", "country": "us"})

info = r.json()

songs_df = pd.DataFrame(info["results"])

songs_df.to_excel("musicas_beatles_info.xlsx")

songs_df
# Out:
#    wrapperType    artistId  collectionId                        artistName  \
# 0    audiobook   366944528     600178079                      June Juanico
# 1    audiobook     2025078     413648314                      Robert Crais
# 2    audiobook     2025078     496048638                      Robert Crais
# 3    audiobook     2025078     280510793                      Robert Crais
# 4    audiobook     2065398     618646386                 Geoffrey Giuliano
# 5    audiobook     2025078     348776614                      Robert Crais
# 6    audiobook     2025078     280512154                      Robert Crais
# 7    audiobook     2025078     280540958                      Robert Crais
# 8    audiobook     2025078     280511286                      Robert Crais
# 9    audiobook     2025078    1052915227                      Robert Crais
# 10   audiobook     2025078    1307088305                      Robert Crais
# ...

# %%
import matplotlib.pyplot as plt

x = [1,2,3,4]
y = [2,3,11,14]

plt.title("Gráfico de linhas criado com Python")

plt.xlabel("Eixo X")
plt.ylabel("Eixo Y")

plt.plot(x, y)
plt.show()

# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
import matplotlib.pyplot as plt

tickers = ["NFLX"]
stock_prices_br = pd.DataFrame()
for t in tickers:
	 stock_prices_br[t] = wb.DataReader(t, data_source = "yahoo", start ="2020-1-1")["Adj Close"]

stock_prices_br.plot(figsize = (15, 6))
plt.show

# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
import matplotlib.pyplot as plt

tickers = ["MGLU3.SA", "BTOW3.SA", "AMZN", "FB", "NFLX"]
stock_prices_br = pd.DataFrame()
for t in tickers:
	stock_prices_br[t] = wb.DataReader(t, data_source = "yahoo", start ="2017-3-1")["Adj Close"]

(stock_prices_br/ stock_prices_br.iloc[0] * 100).plot(figsize = (15, 6));
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
import pandas as pd
import requests
import json

base_site = "https://itunes.apple.com/search"

r = requests.get(base_site, params = {"term": "anitta", "country": "br"})

info = r.json()

songs_df = pd.DataFrame(info["results"])

songs_df.to_excel("musicas_beatles_info.xlsx")

songs_df
# Out:
#    wrapperType  kind    artistId  collectionId     trackId  \
# 0        track  song   597214610     633759630   633759631
# 1        track  song   597214610     664708821   664709261
# 2        track  song   597214610     664708821   664709257
# 3        track  song   597214610     664708821   664709254
# 4        track  song   597214610     664708821   664709255
# 5        track  song   597214610     664708821   664709260
# 6        track  song   597214610     664708821   664709263
# 7        track  song   597214610     664708821   664709256
# 8        track  song   597214610     664708821   664709259
# 9        track  song   597214610     664708821   664709291
# 10       track  song   597214610     664708821   664709267
# 11       track  song   597214610     664708821   664709290
# 12       track  song   597214610    1044543490  1044543493
# 13       track  song   597214610     664708821   664709258
# 14       track  song   597214610     664708821   664709262
# ...

# %%
import matplotlib.pyplot as plt

x = [1,2,3,4]
y = [2,3,11,14]

plt.title("Gráfico de linhas criado com Python")

plt.xlabel("Eixo X")
plt.ylabel("Eixo Y")

plt.plot(x, y)
plt.show()

# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
import matplotlib.pyplot as plt

tickers = ["MMXM3.SA"]
stock_prices_br = pd.DataFrame()
for t in tickers:
    stock_prices_br[t] = wb.DataReader(t, data_source = "yahoo", start="2020-08-1")["Adj Close"]
    
stock_prices_br.plot(figsize = (15, 6))
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
import matplotlib.pyplot as plt

x = [1,2,3,4]
y = [2,3,10,18]

plt.title("Gráfico de linhas feito em Python")

plt.xlabel("Eixo X")
plt.ylabel("Eixo Y")

plt.bar(x, y)
plt.show()
