# %% [markdown]
# <a href="https://colab.research.google.com/github/GabrielMarcuzzo/python4all/blob/main/PROGRAMA__VII__An%C3%A1lise_de_Indicadores_Fundamentalistas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# PROGRAMA VII – Análise de Indicadores Fundamentalistas
# API do site fundamentus.com.br
# PASSO 1 - Instalando Bibliotecas

# !pip install fundamentus
# !pip install requests-cache

# %%
# PROGRAMA VII – Análise de Indicadores Fundamentalistas
# API do site fundamentus.com.br
# PASSO 1 - Instalando Bibliotecas

# !pip install fundamentus
# !pip install requests-cache

# %%
# PASSO 2 - Importando Bibliotecas
import fundamentus
import requests_cache
import requests
import time, logging
import pandas as pd
import matplotlib.pyplot as plt

# %%
# PASSO 3 - Baixando Dados das Ações
df = fundamentus.get_resultado()

# %%
# PASSO 4 - Crianco filtros (Dividend Yield acima da SELIC e Preço/Lucro menor que 10)

filtro1 = df[(df.dy > 0.1475) & (df.pl < 10)]

# %%
filtro1

# %%
filtro1.to_excel("B3_melhores_acoes__2026-03.xlsx")
