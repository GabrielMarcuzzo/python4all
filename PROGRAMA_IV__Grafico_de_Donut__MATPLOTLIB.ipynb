# %% [markdown]
# <a href="https://colab.research.google.com/github/GabrielMarcuzzo/python4all/blob/main/PROGRAMA_IV__Grafico_de_Donut__MATPLOTLIB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Programa IV:

# Gráfico de Donut utilizando a biblioteca Matplotlib.

import matplotlib.pyplot as plt

fig, ax = plt.subplots()
circle = plt.Circle((0, 0),0.64, color="white")
lbls = ["Custo 1", "Custo 2", "Custo 3", "Custo 4", "Custo 5"]
ax.pie([20,20,20,20,20],
       labels=lbls,
       autopct="%1.1f%%",
       pctdistance=.82)
ax.add_artist(circle)
ax.set_title("Gráfico de Donut", fontsize=16)
plt.show()
